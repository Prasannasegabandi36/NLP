# %%
paragraph="""
Sundar Pichai is one of the most well-known technology leaders in the world and is widely recognized for his calm leadership style and strong focus on innovation. Born in Madurai, Tamil Nadu, India, he grew up in a middle-class family and showed great interest in learning and technology from a young age. He studied Metallurgical Engineering at IIT Kharagpur and later continued higher education in the United States, completing an M.S. from Stanford University and an MBA from the Wharton School of the University of Pennsylvania. His career took a major turn when he joined Google in 2004, where he contributed to several important products that shaped modern internet usage. Sundar Pichai played a key role in the development and success of Google Chrome, which became one of the world’s most popular web browsers because of its speed, simplicity, and security. Over time, he also led many other projects including Gmail, Google Drive, Maps, and Android, proving his ability to manage large-scale platforms used by billions of people. In 2015, he became the CEO of Google, and later in 2019, he was appointed CEO of Alphabet Inc., Google’s parent company. As CEO, he has focused on improving artificial intelligence, cloud computing, and digital safety while expanding Google’s products and services to support users globally. Sundar Pichai is respected for his humble personality, clear decision-making, and encouragement of teamwork, and he is often seen as an inspiring example for students and young professionals, especially in India, showing how dedication, education, and hard work can lead to global success.
"""

# %%
import nltk
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences

# %%
nltk.download('averaged_perceptron_tagger')

# %%
#apply  stopwards and filter and then apply stemming
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    word=[word for word in words if word not in set(stopwords.words('english'))]
    #sentences[i]=' '.join(words) #convert all words into sentences
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)

# %%
nltk.pos_tag_sents("Taj mahal is beautiful place")

# %%
for word in "Taj mahal is beautiful place".split():
    print(word)

# %%
for word in "Taj mahal is beautiful place".split():
    print(nltk.pos_tag_sents())

# %%
print(nltk.pos_tag("Taj mahal is beautiful place").split())
