# %%
The Eiffel Tower is one of the most famous monuments in the world. It is located in Paris, France. The tower was built by Gustave Eiffel and was completed in 1889 for the World’s Fair (Exposition Universelle). The Eiffel Tower is made of iron and it is about 324 meters tall. It was once the tallest man-made structure in the world.

Many tourists visit the Eiffel Tower every year. People can go up using lifts or stairs and enjoy a beautiful view of Paris from the top. At night, the tower looks very beautiful because it is decorated with bright lights. The Eiffel Tower is a symbol of France and it shows the importance of art, engineering, and architecture. It is one of the greatest attractions in the world.

# %%
sentence=

# %%
< DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<title>Shiva Mudra Wallpaper</title>

<style>
    body {
        margin: 0;
        height: 100vh;
        background-color: black;     /* Black background */
        display: flex;
        justify-content: center;     /* Horizontal center */
        align-items: center;         /* Vertical center */
    }

    .mudra img {
        width: 300px;                /* Adjust size if needed */
        height: auto;
        filter: drop-shadow(0 0 20px white);
    }
</style>
</head>

<body>
    <div class="mudra">
        <img src="shiva_mudra.png" alt="Shiva Mudra">
    </div>
</body>
</html>

# %%
import nltk
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')

# %%
nltk.download('words')

# %%
nltk.ne_chunk(tag_elements).draw()
