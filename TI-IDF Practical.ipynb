# %%
import pandas as pd
messages=pd.read_csv("C:\Users\sai kumar\downloads\spam.csv")
messages.head()
# Out:
#   Cell In[6], line 2
#     messsages=pd.read_csv("C:\Users\sai kumar/downloads\spam.csv")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.0 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.0 MB 1.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.0 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.0 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.0 MB 917.8 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/11.0 MB 917.8 kB/s eta 0:00:11
#    ------ --------------------------------- 1.8/11.0 MB 854.2 kB/s eta 0:00:11
# ...
