# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
messages=pd.read_csv("C:\Users/sai kumar/Downloads/spam.csv",sep='\t',names=["label","messages"])
# Out:
#   Cell In[7], line 2
#     messages=pd.read_csv("C:\Users/sai kumar/Downloads/spam.csv",sep='\t',names=["label","messages"])
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
## data cleaning and preprocessing
import re
import nltk
nltk.download('stopwords')

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
corpus=[]
for i in range (0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['messages'][i])
    review=review.lower()
    review=review.split()
    reivew=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)

# %%
corpus

# %%
#create the bag of words model
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2500)

# %%
#create the bag of words model
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100,binary=True)

# %%
X=cv.fit_transform(corpus).toarray()

# %%
X.shape

# %% [markdown]
# N GRAMES

# %%
cv.vocabulary_

# %%
##create a bag of worfs model with ngrM
from sklearn.feature_extraction.text import CountVectorizer
## for binary BOW enable binary=True
cv=CountVectorizer(max_features=100,binary=True,ngram_range=(1,1))
X=cv.fit_transform(corpus).toarray()
